# %% [markdown]
# # Synova RAG - Build Vector Database
#
# ## Objective
#
# Convert the multilingual knowledge base into dense vector embeddings using BGE-M3.
#
# The workflow includes:
#
# 1. Load CSV.
# 2. Load BGE-M3.
# 3. Generate Embeddings.
# 4. Save embeddings.npy.

# %% [markdown]
# # 02. Import Libraries

# %%
from pathlib import Path
import sys

import numpy as np
import pandas as pd

from sentence_transformers import SentenceTransformer

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %% [markdown]
# # 03. Project Paths

# %%
PROCESSED_DIR = PROJECT_ROOT / "processed"
VECTOR_DB_DIR = PROJECT_ROOT / "vector_db"

VECTOR_DB_DIR.mkdir(exist_ok=True)

# %% [markdown]
# # Load Embedding Model

# %%
MODEL_NAME = "BAAI/bge-m3"

model = SentenceTransformer(
    MODEL_NAME
)

# %% [markdown]
# # Generate Embeddings

# %%
embeddings = model.encode(

    df["text"].tolist(),

    batch_size=32,

    show_progress_bar=True,

    convert_to_numpy=True,

    normalize_embeddings=True

)
# Out:
# Batches:   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# # Verify Shape

# %%
print(embeddings.shape)
# Out:
# (156, 1024)

# %% [markdown]
# # Save Embeddings

# %%
np.save(

    VECTOR_DB_DIR / "embeddings.npy",

    embeddings

)

print("Embeddings saved successfully.")
# Out:
# Embeddings saved successfully.

# %% [markdown]
# # Quick Test

# %%
print(embeddings[0][:10])
# Out:
# [-0.00119752 -0.00659937 -0.05582459  0.02754573 -0.06109099 -0.02817175
#  -0.03671156 -0.01123376  0.06304102  0.0013134 ]
