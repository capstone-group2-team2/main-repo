# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(
    r"../data/raw/english/sentiment_data.csv")

print(df.shape)
# Out:
# (241145, 3)

# %%
print(f"first 5 rows of df: {df.head()}")
print("================================================")
print(f"Data types and missing values: {df.info()}")
print("================================================")

print(f"Column names: {df.columns.tolist()}")
# Out:
# first 5 rows of df:    Unnamed: 0                                            Comment  Sentiment
# 0           0  lets forget apple pay required brand new iphon...          1
# 1           1  nz retailers don’t even contactless credit car...          0
# 2           2  forever acknowledge channel help lessons ideas...          2
# 3           3  whenever go place doesn’t take apple pay doesn...          0
# 4           4  apple pay convenient secure easy use used kore...          2
# ================================================
# <class 'pandas.DataFrame'>
# RangeIndex: 241145 entries, 0 to 241144
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  241145 non-null  int64
#  1   Comment     240928 non-null  str
#  2   Sentiment   241145 non-null  int64
# dtypes: int64(2), str(1)
# memory usage: 25.9 MB
# Data types and missing values: None
# ================================================
# Column names: ['Unnamed: 0', 'Comment', 'Sentiment']

# %%
df["Sentiment"].value_counts()
# Out:
# Sentiment
# 2    103059
# 1     82972
# 0     55114
# Name: count, dtype: int64

# %%
for label in sorted(df["Sentiment"].unique()):
    print(f"\n===== {label} =====")
    print(df[df["Sentiment"] == label]["Comment"].head(5).to_list())
# Out:
# ===== 0 =====
# ['nz retailers don’t even contactless credit card machines like paywave support apple pay don’t like high fees come', 'whenever go place doesn’t take apple pay doesn’t happen often it’s drag ‘contactless covid’ habits getting apple card i’ve gotten used apple pay get seriously annoyed store doesn’t take feels like shock it’s crazy quickly took shopping routine i’ve officially brainwashed apple feels inconvenient even carry physical card pocket', 'holy crap looking chroma systems back designing power supplies looks like guys went multimeter oscilloscopes terrible making accurate voltage measurements bit adcs looking waveforms', 'every person wired brings show act like theyve front cameras times', 'face describing hops killed “some smell pretty… dank “']
#
# ===== 1 =====
# ['lets forget apple pay required brand new iphone order use significant portion apples user base wasnt able use even wanted successive iphone incorporated technology older iphones replaced number people could use technology increased', 'we’ve hounding bank adopt apple pay understand don’t want extra fees easy quick checkout', 'need apple pay physical credit card', 'cambodia universal qr code system scan send money back forth banks take profit merchant receive payment lot stores supermarkets start abandon pos machine together', 'linus table also linus lets use chair']
#
# ===== 2 =====
# ['forever acknowledge channel help lessons ideas explanations quite helpful youll sit comfort monitor account growth', 'apple pay convenient secure easy use used korean japanese airports need physical credit cards', 'got apple pay south africa it’s widely accepted', 'united states abundance retailers accept apple pay still good carry physical card still large quantity places accept apple pay', 'wow really went town psu test rack thats serious bit kit flexible good choices wouldnt surprise choma start offering bespoke rack psu makers watch videos theyll want make sure passes exact rack really push industry well done open source test interface hardware software']
